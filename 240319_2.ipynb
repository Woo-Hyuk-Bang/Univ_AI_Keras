# %%
#2-3. the gears of neural networks; tensor operation
#A keras layer
# keras.layers.Dense

# %%
#1. Element-wise Operations
import numpy as np

z = x + y # Element-wise addition
z = np.maximum(z, 0.) # Element-wise relu

# %% [markdown]
# stochastic gradient descent 학습
