# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images.shape
# Out:
# (60000, 28, 28)

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
len(train_labels)
# Out:
# 60000

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
test_images.shape
# Out:
# (10000, 28, 28)

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
len(test_labels)
# Out:
# 10000

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
#2-2신경망 구조
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
# 신경망의 핵심 구성 요소는 층. 층은 데이터를 위한 필터라고 생각가능하며, 어떤 데이터가 들어가면 더 유용한 형태로 출력된다.
# 더 구체적으로 층은 주어진 문제에 더 의미 있는 표현을 입력된 데이터로부터 추출한다.
# 대부분의 딥러닝은 간단한 층을 연결하여 구성되어 있고, 점진적으로 데이터를 정제하는 형태를 띈다.
# 신경망이 훈련 준비를 마치기 위해서 컴파일 단계에 이 3가지 요소가 더 필요하다.
# 1. 옵티마이저(optimizer) : 입력도니 데이터를 기반으로 모델을 업데이트하는 매커니즘
# 2. 손실 함수(loss function) : 훈련 데이터에서 모델의 성능을 측정하는 방법으로 모델이 옳은 방향으로 학습할 수 있도록 한다.
# 3. 훈련과 테스트 과정을 모니터링할 지표 : 실습에선 정확도만 고려

# %%
# 2-3. 컴파일 단계
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
# 2-4. 이미지 데이터 준비하기
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255
# 2-5. 모델 훈련하기
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# 2-6. 모델을 사용하여 예측 만들기
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# 2-7. 새로운 데이터에서 모델 평가하기
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"테스트 정확도: {test_acc}")
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 8ms/step - loss: 2.3072 - accuracy: 0.1056
# Epoch 2/5
# 469/469 [==============================] - 4s 9ms/step - loss: 2.3075 - accuracy: 0.1045
# Epoch 3/5
# 469/469 [==============================] - 4s 9ms/step - loss: 2.3071 - accuracy: 0.1062
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 2.3071 - accuracy: 0.1039
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 4ms/step - loss: 2.3166 - accuracy: 0.1010
# 테스트 정확도: 0.10100000351667404
